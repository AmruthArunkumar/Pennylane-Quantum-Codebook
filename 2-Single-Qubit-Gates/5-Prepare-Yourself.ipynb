# %%
import pennylane as qp
import numpy as np
import matplotlib.pyplot as plt

dev = qp.device("default.qubit", wires=1)

# %%
@qp.qnode(dev)
def prepare_state():
    # APPLY OPERATIONS TO PREPARE THE TARGET STATE
    qp.Hadamard(0)
    qp.RZ(5 * np.pi / 4, 0)

    return qp.state()

# %%
prepare_state()
# Out:
# array([-0.27059805-0.65328148j, -0.27059805+0.65328148j])

# %%
@qp.qnode(dev)
def prepare_state():
    # APPLY OPERATIONS TO PREPARE THE TARGET STATE
    qp.RX(np.pi/3, 0)

    return qp.state()

# %%
prepare_state()
# Out:
# array([0.8660254+0.j , 0.       -0.5j])

# %%
v = np.array([0.52889389 - 0.14956775j, 0.67262317 + 0.49545818j])

# %%
# CONSTRUCT A QNODE THAT USES qp.MottonenStatePreparation
# TO PREPARE A QUBIT IN STATE V, AND RETURN THE STATE

@qp.qnode(dev)
def prepare_state(state=v):
    qp.MottonenStatePreparation(state_vector=state, wires=range(1))
    return qp.state()

# %%
# This will draw the quantum circuit and allow you to inspect the output gates
print(prepare_state(v))
print()
print(qp.draw(prepare_state, level="device")(v))
# Out:
# [0.52889389-0.14956775j 0.67262317+0.49545818j]
#
# 0: ──RY(1.98)──RZ(0.91)──GlobalPhase(-0.18)─┤  State
